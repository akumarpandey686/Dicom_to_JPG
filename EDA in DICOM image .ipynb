# %%
#!pip install pylibjpeg pylibjpeg-libjpeg pydicom
from pydicom import dcmread
import pylibjpeg

# %%
ds = dcmread(r"F:\RSNA\train_images\1.2.826.0.1.3680043.61\9.dcm")
arr = ds.pixel_array
print(arr)
# Out:
# [[-2048 -2048 -2048 ... -2048 -2048 -2048]
#  [-2048 -2048 -2048 ... -2048 -2048 -2048]
#  [-2048 -2048 -2048 ... -2048 -2048 -2048]
#  ...
#  [-2048 -2048 -2048 ... -2048 -2048 -2048]
#  [-2048 -2048 -2048 ... -2048 -2048 -2048]
#  [-2048 -2048 -2048 ... -2048 -2048 -2048]]

# %%
ds.PhotometricInterpretation = 'YBR_FULL'
arr = ds.pixel_array

# %%
print(arr)
# Out:
# [[-2048 -2048 -2048 ... -2048 -2048 -2048]
#  [-2048 -2048 -2048 ... -2048 -2048 -2048]
#  [-2048 -2048 -2048 ... -2048 -2048 -2048]
#  ...
#  [-2048 -2048 -2048 ... -2048 -2048 -2048]
#  [-2048 -2048 -2048 ... -2048 -2048 -2048]
#  [-2048 -2048 -2048 ... -2048 -2048 -2048]]

# %% [markdown]
# If you just want to preview dicom images without extracting any information then use the following code. You need to install pydicom python package, you can install using pip install pydicom

# %%
import pydicom as dicom
import matplotlib.pylab as plt

# specify your image path
image_path = r'F:\RSNA\train_images\1.2.826.0.1.3680043.61\9.dcm'
ds = dicom.dcmread(image_path)

plt.imshow(ds.pixel_array)

# %% [raw]
# convert the image to png/jpg then you can do the following

# %%
import pydicom as dicom
import cv2   

# specify your image path
image_path = r'F:\RSNA\train_images\1.2.826.0.1.3680043.61\9.dcm'
ds = dicom.dcmread(image_path)

pixel_array_numpy = ds.pixel_array

image_format = '.jpg' # or '.png'
image_path = image_path.replace('.dcm', image_format)

cv2.imwrite(image_path, pixel_array_numpy)
# Out:
# True

# %%
plt.imshow(image_path.pixel_array)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 plt.imshow(image_path.pixel_array)
#
# AttributeError: 'str' object has no attribute 'pixel_array'
